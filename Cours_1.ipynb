# %%
print("Hello, Jupyter !")
# Out:
# Hello, Jupyter !

# %%
actif = True
ferme = False
nom = "Alice"
phrase = 'Bonjour'
multi = """texte
khdflskj
kjghdfslkjf
ljhbldksjfmld
kjbdflkjds
"""

pi = 3.14159
temp = -2.5
sci = 1.5e10
age = 25
nombre = -10
grand = 10_000_000
print(isinstance(sci, int))
# Out:
# False

# %%
fruits = ["pomme", "banane", "cerise"]
print(fruits[-1])
coords = (48.85, 2.35)


a = list(coords);
a[0] = 1

print(a);
# Out:
# cerise
# [1, 2.35]
